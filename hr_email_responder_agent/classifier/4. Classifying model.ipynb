# %%
pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\chand\anaconda3\lib\site-packages (2.19.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tensorflow<2.20,>=2.19 in c:\users\chand\anaconda3\lib\site-packages (from tf-keras) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.70.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.9.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\chand\anaconda3\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\chand\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras) (0.44.0)
# Requirement already satisfied: rich in c:\users\chand\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\chand\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\chand\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chand\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chand\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chand\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chand\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\chand\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\chand\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\chand\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\chand\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chand\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chand\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chand\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.0)

# %%
# 📌 Step 2: Import Libraries
import psycopg2
import pandas as pd
import os

# 📌 Step 3: Set Up Database Connection (Replace with Your Details)
DATABASE_URL = "dbname='postgres' user='postgres' host='34.59.119.208' password='avantichhaya'"

def connect_db():
    try:
        conn = psycopg2.connect(DATABASE_URL)
        print("✅ Connected to PostgreSQL Cloud SQL")
        return conn
    except Exception as e:
        print("🚨 Connection Error:", e)
        return None

conn = connect_db()
cursor = conn.cursor()
# Out:
# ✅ Connected to PostgreSQL Cloud SQL

# %% [markdown]
# cursor.execute("""
#     UPDATE emails
#     SET classified_category = NULL,
#         escalated = NULL,
#         classification_confidence = NULL
#     WHERE email_id >= 101 AND email_id <= 180;
# """)
# conn.commit()

# %%
from transformers import pipeline

# Step 1: Setup classifier
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# Step 2: Define labels
label_map = {
    "Leave Request": "Requests related to taking leave or vacation",
    "Onboarding": "Questions about new hire onboarding or joining formalities",
    "Job Offer": "Inquiries regarding job offers or employment contracts",
    "Payroll Inquiry": "Questions related to salary, payslips, or payroll processing",
    "Benefits Inquiry": "Questions about insurance, medical, or employee benefits",
    "Resignation & Exit": "Emails about resignation, exit process, or final settlements",
    "Attendance & Timesheet": "Issues about work hours, attendance or timesheets",
    "Recruitment Process": "Questions about interview, screening or hiring stages",
    "Policy Clarification": "Clarification about company policies or procedures",
    "Training & Development": "Queries about training programs or skill development",
    "Work From Home Requests": "Requests or updates regarding remote work",
    "Relocation & Transfer": "Inquiries about internal transfers or relocation",
    "Expense Reimbursement": "Questions about reimbursements or expense claims",
    "IT & Access Issues": "Issues about system access, accounts, or technical problems",
    "Events & Celebrations": "Emails about office events, parties, or celebrations"
}

descriptive_labels = list(label_map.values())

# Step 3: Fetch unclassified emails
cursor.execute("""
    SELECT email_id, subject, body, thread_id, received_at
    FROM emails
    WHERE classified_category IS NULL
    ORDER BY received_at;
""")
emails_to_classify = cursor.fetchall()

print(f"🔎 Found {len(emails_to_classify)} unclassified emails.")

# Step 4: Classify and update category + confidence (NO escalation logic yet)
for email_id, subject, body, thread_id, received_at in emails_to_classify:

    # Fetch previous emails for context
    cursor.execute("""
        SELECT subject, body FROM emails
        WHERE thread_id = %s AND received_at < %s
        ORDER BY received_at;
    """, (thread_id, received_at))
    previous_emails = cursor.fetchall()

    context = ""
    for prev_subj, prev_body in previous_emails:
        context += f"Subject: {prev_subj}\nBody: {prev_body}\n---\n"

    email_text = context + f"Subject: {subject}\nBody: {body}"

    result = classifier(email_text, descriptive_labels)
    predicted_description = result["labels"][0]
    confidence = result["scores"][0]

    predicted_label = next(
        key for key, value in label_map.items() if value == predicted_description
    )

    print(f"📧 Email ID {email_id} → Category: {predicted_label}, Confidence: {round(confidence, 2)}")

    # Update category and confidence only
    cursor.execute("""
        UPDATE emails
        SET classified_category = %s,
            classification_confidence = %s
        WHERE email_id = %s;
    """, (predicted_label, confidence, email_id))

conn.commit()
print("✅ Classification and confidence updated for all emails.")
# Out:
# WARNING:tensorflow:From c:\Users\chand\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Device set to use cpu
# 🔎 Found 0 unclassified emails.
# ✅ Classification and confidence updated for all emails.

# %%
threshold = 0.2  # You can change this anytime

# Reset escalation and categories for all classified records
cursor.execute("""
    UPDATE emails
    SET escalated = NULL,
        classified_category = NULL
    WHERE classification_confidence IS NOT NULL;
""")
conn.commit()

# Apply escalation rule: low confidence → escalated = TRUE and category = 'human_intervention'
cursor.execute("""
    UPDATE emails
    SET escalated = CASE
                      WHEN classification_confidence < %s THEN TRUE
                      ELSE FALSE
                  END,
        classified_category = CASE
                                WHEN classification_confidence < %s THEN 'human_intervention'
                                ELSE classified_category
                              END
    WHERE classification_confidence IS NOT NULL;
""", (threshold, threshold))

conn.commit()
print("✅ Escalation flags and categories updated based on confidence threshold.")
# Out:
# ✅ Escalation flags and categories updated based on confidence threshold.

# %%
# 📌 Step 6: Retrieve Data as DataFrame
df = pd.read_sql("SELECT * FROM emails where escalated=True;", conn)
df
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_52216\28204962.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM emails where escalated=True;", conn)
#    email_id                sender_email                               subject  \
# 0       139          user39@example.com          Interview reschedule request
# 1        25     newsletters@audible.com      90% off plus a bonus $20 credit.
# 2       112          user12@example.com               Negotiating offer terms
# 3        27  email@market.temuemail.com            Your loyalty has paid off!
# 4       137          user37@example.com             Application status update
# 5       140          user40@example.com            Job application withdrawal
# 6        34  email@market.temuemail.com  A massive thank you! $6 OFF for you!
# 7       177          user77@example.com                   Assistance required
# 8        30  email@market.temuemail.com            Your Purchase, Our Thanks!
#
#                                                 body  \
# 0                 I need to reschedule my interview.
# 1  audible https://www.audible.com/sign-in?rdpath...
# 2  I would like to discuss the offered compensati...
# 3  ----------------------------------------------...
# 4          What is the status of my job application?
# 5           I would like to withdraw my application.
# 6  ----------------------------------------------...
# 7     Im unsure who to contact regarding this issue.
# 8  ----------------------------------------------...
#
#                  received_at    classified_category         status  escalated  \
# 0 2025-03-24 17:52:00.000000    Recruitment Process        pending       True
# 1 2024-11-27 09:44:15.000000  Events & Celebrations  NOT RESPONDED       True
# 2 2025-03-31 11:32:00.000000              Job Offer        pending       True
# 3 2024-11-27 01:10:05.000000  Events & Celebrations  NOT RESPONDED       True
# 4 2025-03-24 09:24:00.000000     human_intervention        pending       True
# 5 2025-03-23 10:56:00.000000             Onboarding        pending       True
# 6 2024-11-20 01:17:09.000000     human_intervention  NOT RESPONDED       True
# 7 2025-03-31 17:40:00.000000     human_intervention        pending       True
# 8 2025-05-04 00:14:43.392800     human_intervention  NOT RESPONDED       True
#
#    thread_id  classification_confidence response_email  learn
# 0      218.0                   0.176617           None   None
# 1        NaN                   0.129796           None   None
# 2      206.0                   0.179425           None   None
# 3        NaN                   0.190893           None  False
# 4      217.0                   0.163099           None   None
# 5      219.0                   0.143597           None   True
# 6        NaN                   0.199713           None   None
# 7      230.0                   0.194488           None   None
# 8        NaN                   0.198693           None   None

# %%
# 📌 Step 6: Retrieve Data as DataFrame
df = pd.read_sql("SELECT * FROM emails where email_id=27;", conn)
df
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_52216\1309588657.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM emails where email_id=27;", conn)
#    email_id                sender_email                     subject  \
# 0        27  email@market.temuemail.com  Your loyalty has paid off!
#
#                                                 body         received_at  \
# 0  ----------------------------------------------... 2024-11-27 01:10:05
#
#      classified_category         status  escalated thread_id  \
# 0  Events & Celebrations  NOT RESPONDED       True      None
#
#    classification_confidence response_email  learn
# 0                   0.190893           None  False
